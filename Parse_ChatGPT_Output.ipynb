# %% [markdown]
# # Preparation

# %% [markdown]
# Following the instructions in https://jcubic.github.io/chat-gpt/, install the chatgpt saving bookmark. Open a ChatGPT conversation you wish to download and type into the browser bar the name of the bookmark and click on it. You will be prompted to save an html containing the ChatGPT conversation. Upload that html to jupyterlab and fill in html names as appropriate in the given examples.

# %% [markdown]
# # Imports

# %%
import pandas as pd
import io
import re

# If you do not yet have BeautifulSoup4 and python-docx installed you will have to run:
# pip3 install beautifulsoup4 python-docx
# or
# conda install -c conda-forge beautifulsoup4 python-docx
from bs4 import BeautifulSoup
from docx import Document

# %% [markdown]
# # Bsoup Parsing Example Chat 1

# %% [markdown]
# ## Parse ChatGPT

# %%
chatgpt_html_1 = "chat-gpt-heidegger-technicity-meaning.html"

# %%
with open(chatgpt_html_1, "r", encoding="utf-8") as f:
    html_content = f.read()

# %%
tags_to_find = ["h1", "h2", "h3", "p", "table", "blockquote", "div"]
paracodes = []
paras = []

soup = BeautifulSoup(html_content, "html.parser")
conversation = soup.find("body")
title = conversation.find("div", attrs={"class": "whitespace-pre-wrap"}).get_text()
print(title)

skipnext = False
for tag in conversation.find_all(tags_to_find):
    if skipnext:
        # very clumsy kludge to avoid picking out quote paras twice
        skipnext = False
        continue

    # Preserving User Queries
    if tag.name == "div" and "class" in tag.attrs and any(["user-message" in attr for attr in tag.attrs["class"]]):
        querytext = tag.get_text()
        paracodes.append("User Query")
        paras.append(" "*40+"User Query: "+querytext)
        continue

    # Handle Block Quotes
    if tag.name == "blockquote":
        # parse out block quotes and convert to their underlying content
        rawquotecontent = str(tag)
        quotecontent = BeautifulSoup(rawquotecontent, "html.parser")

        # empty attr information
        for subtag in quotecontent.find_all(True):
            subtag.attrs = {}

        # strip blockquote tag
        dequoted = quotecontent.blockquote.decode_contents()
        dequoted = str(dequoted).replace("<p>", "<p>QuoteStart").strip() # add quote marker before blockquotes

        # reparse to content of the quote tag
        tag = BeautifulSoup(dequoted, "html.parser").find(tags_to_find)

        # very clumsy kludge to avoid picking out quote paras twice
        skipnext = True

    # parse down to header, paragraph, or table sections
    content = str(tag)
    if tag.name == "h1" or tag.name == "h2" or tag.name == "h3" or tag.name == "p":
        # clear out outer tags, p, h1, h2, h3, as well as extraneous attr information
        rawtext = BeautifulSoup(content, "html.parser")

        # empty attr information
        for subtag in rawtext.find_all(True):  # Iterate over all tags
            subtag.attrs = {}  # Set the attributes dictionary to empty

        # decode_contents strips the outer tag
        if tag.name == "p":
            text = rawtext.p.decode_contents()
        elif tag.name == "h1":
            text = rawtext.h1.decode_contents()
        elif tag.name == "h2":
            text = rawtext.h2.decode_contents()
        elif tag.name == "h3":
            text = rawtext.h3.decode_contents()

        print(f"Tag name: {tag.name}, Text content: {text}")
        paracodes.append(tag.name)
        paras.append(text)
    elif tag.name == "table":
        # use pandas to convert a chatgpt html table into a pandas dataframe
        table = pd.read_html(io.StringIO(str(tag)))[0]

        print(tag.name, table)
        paracodes.append(tag.name)
        paras.append(table)
# Out:
# What does Heidegger mean in his interview "Only a god can save us" when he says "technicity"?
# Tag name: p, Text content: In his 1966 <em>Der Spiegel</em> interview “Only a God Can Save Us” (<em>Nur noch ein Gott kann uns retten</em>), Martin Heidegger uses the term <strong>“Technicity”</strong> (<em>die Technik</em> or more precisely <em>die Wesensbestimmung der Technik</em>, “the essence of technology”) to refer <strong>not simply to machines or technological devices</strong>, but to a <strong>mode of revealing</strong> (<em>eine Weise des Entbergens</em>)—a fundamental way in which the modern world discloses or interprets Being.
# Tag name: p, Text content: Here’s a breakdown of what Heidegger means:
# Tag name: h3, Text content: 1. <strong>Technicity ≠ Technology</strong>
# Tag name: p, Text content: Heidegger distinguishes between:
# Tag name: p, Text content: <strong>Technology as tools or machines</strong> (<em>instrumental, anthropological definition</em>) — the everyday sense.
# Tag name: p, Text content: <strong>Technicity as a worldview</strong> — the <em>essence</em> of modern technology, which organizes and reveals the world in a specific way.
# Tag name: p, Text content: Technicity is <strong>not something humans control</strong>; rather, it is <strong>a historical destiny</strong> (<em>Geschick</em>) in which Being itself unfolds to humans as <em>standing-reserve</em> (<em>Bestand</em>). This means that under technicity, everything — nature, people, even thought — appears primarily as <strong>resources to be optimized, ordered, and used</strong>.
# Tag name: h3, Text content: 2. <strong>Technicity as “Enframing” (<em>Gestell</em>)</strong>
# Tag name: p, Text content: In his essay <em>The Question Concerning Technology</em> (1954), Heidegger calls the essence of technology <strong>Gestell</strong> — “enframing.”
# Technicity, in the interview, is a shorthand for this same idea. It names <strong>the totalizing frame</strong> within which the modern world discloses beings: as objects to be calculated, controlled, and stored for use.
# Tag name: p, Text content: In the interview he says:
# Tag name: p, Text content: QuoteStart“The essence of technology is nothing technological.”
# Meaning: technicity is a <strong>metaphysical condition</strong>, not a collection of gadgets. It’s a way of thinking — or a destiny of Being — that predefines what counts as “real.”
# Tag name: h3, Text content: 3. <strong>The Danger of Technicity</strong>
# Tag name: p, Text content: For Heidegger, the danger is that technicity <strong>obscures other ways of revealing truth</strong>.
# If everything appears only as a resource — as energy to be extracted or data to be processed — then <strong>poetic, sacred, or meditative modes of Being</strong> are forgotten.
# Tag name: p, Text content: He says modern humanity is “<em>claimed by</em>” technicity rather than in command of it. This loss of alternative ways of understanding Being leads to <strong>a spiritual impoverishment</strong>, even as technical power increases.
# Tag name: h3, Text content: 4. <strong>Why “Only a God Can Save Us”</strong>
# Tag name: p, Text content: In the interview, Heidegger says:
# Tag name: p, Text content: QuoteStart“Philosophy will not be able to bring about a direct change in the present state of the world. Only a god can still save us.”
# Tag name: p, Text content: By this, he means that <strong>only a radically different “disclosure of Being”</strong> — comparable in depth to a religious or poetic revelation — can free us from the grip of technicity. Not a literal deity, but a new, non-technological way in which Being might show itself.
# Tag name: h3, Text content: <strong>In short:</strong>
# Tag name: p, Text content: <strong>Technicity</strong> in Heidegger’s interview refers to:
# Tag name: p, Text content: QuoteStartThe metaphysical condition in which all beings appear as objects of control and use — the modern mode of revealing that enframes the world as “standing-reserve.”
# Tag name: p, Text content: It’s both <strong>a destiny of Western metaphysics</strong> and <strong>the horizon within which modern life unfolds</strong>.
# Tag name: p, Text content: Would you like me to include a few key passages from the interview itself (in German and English) where he uses <em>Technik</em> or refers to this concept explicitly?
# Tag name: p, Text content: Excellent — here are the <strong>key excerpts</strong> from Martin Heidegger’s 1966 <em>Der Spiegel</em> interview, <em>“Nur noch ein Gott kann uns retten”</em> (“Only a God Can Save Us”), with the relevant parts on <strong>technicity (die Technik)</strong> and brief commentary for each.
# Tag name: p, Text content: I’ll give each in <strong>German</strong>, <strong>English translation</strong>, and <strong>commentary</strong>.
# Tag name: h2, Text content: 🧩 1. The Historical Destiny of Technicity
# Tag name: p, Text content: <strong>German (original):</strong>
# Tag name: p, Text content: QuoteStart„Die Wissenschaft denkt nicht. … Sie ist auf die Herstellung des Forschens als solchen in der Weise der technischen Organisation angewiesen. Diese Organisation aber ist heute weltweit. … Die Technik ist nicht etwas Menschliches, sondern sie ist ein Geschick des Seins selbst.“
# Tag name: p, Text content: <strong>English translation:</strong>
# Tag name: p, Text content: QuoteStart“Science does not think. … It depends on the production of research as such in the manner of technical organization. This organization, however, is now worldwide. … Technology is not something human, but rather a destiny of Being itself.”
# Tag name: p, Text content: <strong>Commentary:</strong>
# Heidegger draws a sharp line between <strong>science as thinking</strong> and <strong>science as technical production</strong>. The latter—modern research—is structured by <strong>technicity</strong>: an organizational, global process that determines how knowledge and being appear.
# This is why he says technology (<em>die Technik</em>) is not just a human creation; it is a <strong>“Geschick des Seins,”</strong> a fate or sending of Being itself. Humanity finds itself already within this destiny.
# Tag name: h2, Text content: ⚙️ 2. The Uncontrollability of Technicity
# Tag name: p, Text content: <strong>German:</strong>
# Tag name: p, Text content: QuoteStart„Wir stehen in der Technik, und zwar so, daß die Technik uns in ihrem Wesen beansprucht. … Der Mensch steht heute in der Technik nicht mehr als deren Herr, sondern als der, der von ihr beansprucht wird.“
# Tag name: p, Text content: <strong>English:</strong>
# Tag name: p, Text content: QuoteStart“We stand within technology, and in such a way that technology claims us in its essence. … Man today no longer stands as the master of technology, but as the one who is claimed by it.”
# Tag name: p, Text content: <strong>Commentary:</strong>
# This is central to his notion of <strong>Gestell</strong> (enframing): technicity is a <em>power that claims humans</em>, not something they merely operate. Even efforts to “control” technology (ethically, politically) already presuppose the same technical mindset. Thus, technicity defines <strong>our very relation to the world</strong>, not just our tools.
# Tag name: h2, Text content: 🌍 3. Technicity as the Global Condition
# Tag name: p, Text content: <strong>German:</strong>
# Tag name: p, Text content: QuoteStart„Die planetarische Bewegung der Technik ist ein einheitliches Geschehen, in das alle Kulturen eingetreten sind, oder eintreten müssen.“
# Tag name: p, Text content: <strong>English:</strong>
# Tag name: p, Text content: QuoteStart“The planetary movement of technology is a unified event into which all cultures have entered—or must enter.”
# Tag name: p, Text content: <strong>Commentary:</strong>
# Here he anticipates what we would now call <strong>globalization</strong> or <strong>technological modernity</strong>. Technicity is not a Western invention that can be exported or rejected; it is a <strong>planetary event</strong>, an ontological horizon that reorganizes every culture’s relation to Being. In this sense, it’s not avoidable—only transformable through a new “revelation.”
# Tag name: h2, Text content: 🕯️ 4. The Danger and the Saving Power
# Tag name: p, Text content: <strong>German:</strong>
# Tag name: p, Text content: QuoteStart„Das Wesen der Technik birgt in sich das Rettende. … Vielleicht können wir, wenn wir das Wesen der Technik bedenken, uns vorbereiten auf die Ankunft des Gottes oder auf die Abwesenheit des Gottes im Untergang.“
# Tag name: p, Text content: <strong>English:</strong>
# Tag name: p, Text content: QuoteStart“The essence of technology harbors within itself the saving power. … Perhaps when we ponder the essence of technology, we can prepare ourselves for the coming of the god—or for the absence of the god in the downfall.”
# Tag name: p, Text content: <strong>Commentary:</strong>
# This echoes the line from his essay <em>The Question Concerning Technology</em>:
# Tag name: p, Text content: QuoteStart“Where danger is, grows the saving power.” (<em>Wo aber Gefahr ist, wächst das Rettende auch.</em>)
# Tag name: p, Text content: For Heidegger, thinking deeply about technicity itself—recognizing it as a destiny rather than merely a collection of machines—could open humanity to a <strong>new relation to Being</strong>, possibly a divine or poetic disclosure that “saves” us.
# Tag name: h2, Text content: 🪞 5. Why “Only a God Can Save Us”
# Tag name: p, Text content: <strong>German:</strong>
# Tag name: p, Text content: QuoteStart„Nur noch ein Gott kann uns retten. … Das Denken kann uns nicht unmittelbar zur Umkehr bringen. … Wir können uns nur vorbereiten, indem wir das Denken vorbereiten, das aus der Erfahrung der Wahrheit des Seins hervorgeht.“
# Tag name: p, Text content: <strong>English:</strong>
# Tag name: p, Text content: QuoteStart“Only a god can still save us. … Thinking cannot bring about a direct reversal. … We can only prepare ourselves by awakening the thinking that arises from the experience of the truth of Being.”
# Tag name: p, Text content: <strong>Commentary:</strong>
# Heidegger does <strong>not</strong> mean a return to theology. The “god” here is a <strong>symbol for a new dispensation of Being</strong>—a radically different way in which truth might manifest. The path lies in <strong>thinking the essence of technicity</strong> without immediately seeking to dominate or escape it.
# Tag name: h3, Text content: ✳️ Summary
# table           Concept         Heidegger’s Term  \
# 0      Technicity     die Technik, Gestell
# 1  Human position  beansprucht (“claimed”)
# 2          Danger                   Gefahr
# 3    Saving power             das Rettende
# 4       The “god”                 der Gott
#
#                                              Meaning
# 0  The ontological framework in which Being is re...
# 1  Humans are not masters of technology; they are...
# 2  The loss of alternative ways of revealing trut...
# 3  The possibility that thinking about technicity...
# 4  A metaphor for the advent of a new mode of rev...
# Tag name: p, Text content: Would you like me to show how <strong>“technicity” in this interview</strong> connects to his earlier writings (like <em>Being and Time</em> or <em>The Question Concerning Technology</em>) — i.e., how it grows out of his evolving idea of Being as “disclosure” (<em>aletheia</em>)?

# %% [markdown]
# ## Preparing Word Doc

# %%
document = Document()
currenttype = None
for paracode, para in zip(paracodes, paras):
    if paracode == "table":
        # add a table to the end and create a reference variable
        # extra row is so we can add the header row
        table = document.add_table(para.shape[0]+1, para.shape[1])
        table.style = 'Table Grid'
        
        # add the header rows.
        for j in range(para.shape[-1]):
            table.cell(0,j).text = para.columns[j]
        
        # add the rest of the data frame
        for i in range(para.shape[0]):
            for j in range(para.shape[-1]):
                table.cell(i+1,j).text = str(para.values[i,j])
    else:
        if paracode == "User Query":
            heading = document.add_heading("")
            currenttype = "heading"
        elif paracode == "h1":
            heading = document.add_heading("")
            currenttype = "heading"
        elif paracode == "h2":
            heading = document.add_heading("", level=2)
            currenttype = "heading"
        elif paracode == "h3":
            heading = document.add_heading("", level=3)
            currenttype = "heading"
        else:
            # handle quotes
            if para.startswith("QuoteStart"):
                para = para.replace("QuoteStart", "")
                paragraph = document.add_paragraph("", style="Quote")
            else:
                paragraph = document.add_paragraph("")
            currenttype = "paragraph"
    
        # match on text formatting. Note that raw html can't control font size, as that requires CSS.
        # surely a better way to control formatting but this is a rush job
        sections = re.split("[<>]{1}", para)
    
        strong = False
        emphasis = False
        underline = False
        for section in sections:
            if section == "strong":
                strong = True
            elif section == "em":
                emphasis = True
            elif section == "u":
                underline = True
            elif section == "/strong":
                strong = False
            elif section == "/em":
                emphasis = False
            elif section == "/u":
                underline = False
            else:
                if currenttype == "heading":
                    run = heading.add_run(section)
                elif currenttype == "paragraph":
                    run = paragraph.add_run(section)
                if strong:
                    run.bold = True
                else:
                    run.bold = False
                if emphasis:
                    run.italic = True
                else:
                    run.italic = False
                if underline:
                    run.underline = True
                else:
                    run.underline = False

# %%
document.save('Heidegger_Technicity.docx')

# %% [markdown]
# # Bsoup Parsing Example Chat 2

# %% [markdown]
# ## Parse ChatGPT

# %%
chatgpt_html_1 = "chat-gpt-naval-shipyard-locations.html"

# %%
with open(chatgpt_html_1, "r", encoding="utf-8") as f:
    html_content = f.read()

# %%
tags_to_find = ["h1", "h2", "h3", "p", "table", "blockquote", "div"]
paracodes = []
paras = []

soup = BeautifulSoup(html_content, "html.parser")
conversation = soup.find("body")
title = conversation.find("div", attrs={"class": "whitespace-pre-wrap"}).get_text()
print(title)

skipnext = False
for tag in conversation.find_all(tags_to_find):
    if skipnext:
        # very clumsy kludge to avoid picking out quote paras twice
        skipnext = False
        continue

    # Preserving User Queries
    if tag.name == "div" and "class" in tag.attrs and any(["user-message" in attr for attr in tag.attrs["class"]]):
        querytext = tag.get_text()
        paracodes.append("User Query")
        paras.append(" "*40+"User Query: "+querytext)
        continue

    # Handle Block Quotes
    if tag.name == "blockquote":
        # parse out block quotes and convert to their underlying content
        rawquotecontent = str(tag)
        quotecontent = BeautifulSoup(rawquotecontent, "html.parser")

        # empty attr information
        for subtag in quotecontent.find_all(True):
            subtag.attrs = {}

        # strip blockquote tag
        dequoted = quotecontent.blockquote.decode_contents()
        dequoted = str(dequoted).replace("<p>", "<p>QuoteStart").strip() # add quote marker before blockquotes

        # reparse to content of the quote tag
        tag = BeautifulSoup(dequoted, "html.parser").find(tags_to_find)

        # very clumsy kludge to avoid picking out quote paras twice
        skipnext = True

    # parse down to header, paragraph, or table sections
    content = str(tag)
    if tag.name == "h1" or tag.name == "h2" or tag.name == "h3" or tag.name == "p":
        # clear out outer tags, p, h1, h2, h3, as well as extraneous attr information
        rawtext = BeautifulSoup(content, "html.parser")

        # empty attr information
        for subtag in rawtext.find_all(True):  # Iterate over all tags
            subtag.attrs = {}  # Set the attributes dictionary to empty

        # decode_contents strips the outer tag
        if tag.name == "p":
            text = rawtext.p.decode_contents()
        elif tag.name == "h1":
            text = rawtext.h1.decode_contents()
        elif tag.name == "h2":
            text = rawtext.h2.decode_contents()
        elif tag.name == "h3":
            text = rawtext.h3.decode_contents()

        print(f"Tag name: {tag.name}, Text content: {text}")
        paracodes.append(tag.name)
        paras.append(text)
    elif tag.name == "table":
        # use pandas to convert a chatgpt html table into a pandas dataframe
        table = pd.read_html(io.StringIO(str(tag)))[0]

        print(tag.name, table)
        paracodes.append(tag.name)
        paras.append(table)
# Out:
# Are San Diego, Charleston, and Groton Naval Shipyards?
# Tag name: p, Text content: Short answer: <strong>Only Groton is an active naval shipyard today.</strong>
# San Diego is not a shipyard, and Charleston <em>was</em> one but closed decades ago.
# Tag name: p, Text content: Here’s the breakdown:
# Tag name: h2, Text content: <strong>San Diego</strong>
# Tag name: p, Text content: <strong>Not a naval shipyard.</strong>
# Tag name: p, Text content: San Diego has <em>Naval Base San Diego</em>, which is a major <strong>fleet homeport</strong>, not a construction or heavy-repair shipyard.
# Tag name: p, Text content: Some private yards (e.g., NASSCO) do shipbuilding/repair in San Diego, but they are <strong>not naval shipyards</strong>.
# Tag name: h2, Text content: <strong>Charleston (South Carolina)</strong>
# Tag name: p, Text content: <strong>Was a naval shipyard, but no longer.</strong>
# Tag name: p, Text content: The <strong>Charleston Naval Shipyard</strong> operated from 1901 to 1996.
# Tag name: p, Text content: It closed as part of the post-Cold War base realignment (BRAC).
# Tag name: p, Text content: The site is now a mixed commercial/government facility (e.g., Coast Guard, private ship repair companies).
# Tag name: h2, Text content: <strong>Groton (Connecticut)</strong>
# Tag name: p, Text content: <strong>Yes—this is a current shipyard.</strong>
# Tag name: p, Text content: Groton is home to <strong>General Dynamics Electric Boat</strong>, which builds and overhauls U.S. Navy submarines.
# Tag name: p, Text content: It is one of the two primary U.S. submarine shipyards (the other is Newport News in Virginia).
# Tag name: h3, Text content: <strong>Summary</strong>
# table      Location Active Naval Shipyard?  \
# 0   San Diego                   ❌ No
# 1  Charleston     ❌ No (closed 1996)
# 2      Groton                 ✔️ Yes
#
#                                                Notes
# 0  Fleet base; private ship repair exists but not...
# 1                            Historic naval shipyard
# 2                   Electric Boat submarine shipyard
# Tag name: p, Text content: If you want, I can also list all current U.S. naval shipyards.

# %% [markdown]
# ## Preparing Word Doc

# %%
document = Document()
currenttype = None
for paracode, para in zip(paracodes, paras):
    if paracode == "table":
        # add a table to the end and create a reference variable
        # extra row is so we can add the header row
        table = document.add_table(para.shape[0]+1, para.shape[1])
        table.style = 'Table Grid'
        
        # add the header rows.
        for j in range(para.shape[-1]):
            table.cell(0,j).text = para.columns[j]
        
        # add the rest of the data frame
        for i in range(para.shape[0]):
            for j in range(para.shape[-1]):
                table.cell(i+1,j).text = str(para.values[i,j])
    else:
        if paracode == "User Query":
            heading = document.add_heading("")
            currenttype = "heading"
        elif paracode == "h1":
            heading = document.add_heading("")
            currenttype = "heading"
        elif paracode == "h2":
            heading = document.add_heading("", level=2)
            currenttype = "heading"
        elif paracode == "h3":
            heading = document.add_heading("", level=3)
            currenttype = "heading"
        else:
            # handle quotes
            if para.startswith("QuoteStart"):
                para = para.replace("QuoteStart", "")
                paragraph = document.add_paragraph("", style="Quote")
            else:
                paragraph = document.add_paragraph("")
            currenttype = "paragraph"
    
        # match on text formatting. Note that raw html can't control font size, as that requires CSS.
        # surely a better way to control formatting but this is a rush job
        sections = re.split("[<>]{1}", para)
    
        strong = False
        emphasis = False
        underline = False
        for section in sections:
            if section == "strong":
                strong = True
            elif section == "em":
                emphasis = True
            elif section == "u":
                underline = True
            elif section == "/strong":
                strong = False
            elif section == "/em":
                emphasis = False
            elif section == "/u":
                underline = False
            else:
                if currenttype == "heading":
                    run = heading.add_run(section)
                elif currenttype == "paragraph":
                    run = paragraph.add_run(section)
                if strong:
                    run.bold = True
                else:
                    run.bold = False
                if emphasis:
                    run.italic = True
                else:
                    run.italic = False
                if underline:
                    run.underline = True
                else:
                    run.underline = False

# %%
document.save('Naval_Shipyards.docx')

# %% [markdown]
# # Bsoup Parsing Example Chat 3

# %% [markdown]
# ## Parse ChatGPT

# %%
chatgpt_html_1 = "chat-gpt-spontaneous-moral-heroism.html"

# %%
with open(chatgpt_html_1, "r", encoding="utf-8") as f:
    html_content = f.read()

# %%
tags_to_find = ["h1", "h2", "h3", "p", "table", "blockquote", "div"]
paracodes = []
paras = []

soup = BeautifulSoup(html_content, "html.parser")
conversation = soup.find("body")
title = conversation.find("div", attrs={"class": "whitespace-pre-wrap"}).get_text()
print(title)

skipnext = False
for tag in conversation.find_all(tags_to_find):
    if skipnext:
        # very clumsy kludge to avoid picking out quote paras twice
        skipnext = False
        continue

    # Preserving User Queries
    if tag.name == "div" and "class" in tag.attrs and any(["user-message" in attr for attr in tag.attrs["class"]]):
        querytext = tag.get_text()
        paracodes.append("User Query")
        paras.append(" "*40+"User Query: "+querytext)
        continue

    # Handle Block Quotes
    if tag.name == "blockquote":
        # parse out block quotes and convert to their underlying content
        rawquotecontent = str(tag)
        quotecontent = BeautifulSoup(rawquotecontent, "html.parser")

        # empty attr information
        for subtag in quotecontent.find_all(True):
            subtag.attrs = {}

        # strip blockquote tag
        dequoted = quotecontent.blockquote.decode_contents()
        dequoted = str(dequoted).replace("<p>", "<p>QuoteStart").strip() # add quote marker before blockquotes

        # reparse to content of the quote tag
        tag = BeautifulSoup(dequoted, "html.parser").find(tags_to_find)

        # very clumsy kludge to avoid picking out quote paras twice
        skipnext = True

    # parse down to header, paragraph, or table sections
    content = str(tag)
    if tag.name == "h1" or tag.name == "h2" or tag.name == "h3" or tag.name == "p":
        # clear out outer tags, p, h1, h2, h3, as well as extraneous attr information
        rawtext = BeautifulSoup(content, "html.parser")

        # empty attr information
        for subtag in rawtext.find_all(True):  # Iterate over all tags
            subtag.attrs = {}  # Set the attributes dictionary to empty

        # decode_contents strips the outer tag
        if tag.name == "p":
            text = rawtext.p.decode_contents()
        elif tag.name == "h1":
            text = rawtext.h1.decode_contents()
        elif tag.name == "h2":
            text = rawtext.h2.decode_contents()
        elif tag.name == "h3":
            text = rawtext.h3.decode_contents()

        print(f"Tag name: {tag.name}, Text content: {text}")
        paracodes.append(tag.name)
        paras.append(text)
    elif tag.name == "table":
        # use pandas to convert a chatgpt html table into a pandas dataframe
        table = pd.read_html(io.StringIO(str(tag)))[0]

        print(tag.name, table)
        paracodes.append(tag.name)
        paras.append(table)
# Out:
# There is a term for acts of instinctive heroism undertaken in situations one could never have foreseen happening before the moment that required it. The passengers who attempted to storm the cockpit on Flight 93 embody it. So did Liviu Librescu in barricading the door to protect his students. So also every soldier who jumped on a grenade to save his comrades. What is this term and what other examples do you know of that embody it?
# Tag name: p, Text content: The term you’re reaching for is most often <strong>“moral courage”</strong>, but in the very specific sense you’re describing—<em>unpremeditated, instinctive self-sacrifice in an unforeseeable crisis</em>—the phrase that fits best is:
# Tag name: h2, Text content: <strong>“Spontaneous moral heroism”</strong>
# Tag name: p, Text content: (also sometimes called <strong>“situational heroism”</strong>)
# Tag name: p, Text content: This isn’t a single canonical word in everyday English, but it <em>is</em> a well-established concept in moral psychology and ethics.
# Tag name: h2, Text content: Why this term fits your examples
# Tag name: p, Text content: What unites Flight 93, Liviu Librescu, and the soldier who falls on a grenade is that:
# Tag name: p, Text content: <strong>There was no prior plan or training for that exact moment</strong>
# Tag name: p, Text content: <strong>No time for deliberation</strong>
# Tag name: p, Text content: <strong>The act involved near-certain personal cost</strong>
# Tag name: p, Text content: <strong>The choice emerged instantly from character, not calculation</strong>
# Tag name: p, Text content: Researchers like <strong>Philip Zimbardo</strong> (of Stanford Prison Experiment fame) use <em>situational heroism</em> to describe acts that arise when ordinary people respond extraordinarily to sudden moral emergencies.
# Tag name: p, Text content: Zimbardo contrasts this with:
# Tag name: p, Text content: <strong>Planned heroism</strong> (firefighters, lifeguards, soldiers on patrol)
# Tag name: p, Text content: <strong>Role-based heroism</strong> (doing one’s duty)
# Tag name: p, Text content: <strong>Spontaneous heroism</strong> (no role, no rehearsal, no expectation)
# Tag name: p, Text content: Your examples fall squarely into the last category.
# Tag name: h2, Text content: Closely related terms (and why they’re not quite right)
# Tag name: h3, Text content: <strong>Moral courage</strong>
# Tag name: p, Text content: ✔ Emphasizes ethical resolve
# Tag name: p, Text content: ✘ Often involves <em>deliberation</em> and sustained opposition (e.g., whistleblowers)
# Tag name: h3, Text content: <strong>Altruistic self-sacrifice</strong>
# Tag name: p, Text content: ✔ Describes the outcome precisely
# Tag name: p, Text content: ✘ Clinical, evolutionary, emotionally flat
# Tag name: h3, Text content: <strong>Virtue ethics / Arete</strong>
# Tag name: p, Text content: ✔ Aristotle would say these acts reveal a formed character
# Tag name: p, Text content: ✘ Not a commonly used descriptive term for events
# Tag name: h3, Text content: <strong>The “Good Samaritan”</strong>
# Tag name: p, Text content: ✔ Captures moral instinct
# Tag name: p, Text content: ✘ Usually non-lethal risk and somewhat foreseeable
# Tag name: h2, Text content: Other powerful examples of <strong>spontaneous moral heroism</strong>
# Tag name: h3, Text content: Civilian, sudden-crisis cases
# Tag name: p, Text content: <strong>Wesley Autrey</strong>, the “Subway Hero,” who jumped onto the tracks to shield a stranger from an oncoming train
# Tag name: p, Text content: <strong>Arland D. Williams Jr.</strong>, Air Florida Flight 90 passenger, who repeatedly passed the rescue line to others before drowning
# Tag name: p, Text content: <strong>The bystanders at the 2017 London Bridge attack</strong> who charged armed attackers with chairs and fire extinguishers
# Tag name: h3, Text content: Educational and protective acts
# Tag name: p, Text content: <strong>Aaron Feis and Chris Hixon</strong>, teachers at Marjory Stoneman Douglas High School, who ran toward gunfire
# Tag name: p, Text content: <strong>Sandy Hook staff members</strong> who shielded children with their bodies
# Tag name: h3, Text content: Wartime and disaster contexts
# Tag name: p, Text content: Soldiers jumping on grenades (the paradigmatic case)
# Tag name: p, Text content: <strong>Mykhailo Dianov</strong> and others who held positions in Mariupol long after survival odds vanished
# Tag name: p, Text content: Nuclear plant workers at <strong>Chernobyl</strong> who entered lethal radiation zones to prevent wider catastrophe
# Tag name: h3, Text content: Ancient and literary analogues
# Tag name: p, Text content: <strong>Titus Manlius’ soldiers</strong> in Roman histories who chose death to hold a line
# Tag name: p, Text content: <strong>Sydney Carton</strong> in <em>A Tale of Two Cities</em> (“It is a far, far better thing…”)
# Tag name: p, Text content: <strong>Beowulf’s retainer Wiglaf</strong>, the only one who stands with him against the dragon
# Tag name: h2, Text content: Why this kind of heroism matters philosophically
# Tag name: p, Text content: These acts are unsettling because they:
# Tag name: p, Text content: <strong>Cannot be explained by incentives</strong>
# Tag name: p, Text content: <strong>Do not rely on identity or ideology</strong>
# Tag name: p, Text content: <strong>Occur faster than conscious reasoning</strong>
# Tag name: p, Text content: They suggest that:
# Tag name: p, Text content: QuoteStartCharacter is real,
# virtue can be habituated,
# and some moral truths live deeper than thought.
# Tag name: p, Text content: Or, as Hannah Arendt put it in a related context: <em>in emergencies, people reveal who they are</em>.
# Tag name: h3, Text content: If you’d like
# Tag name: p, Text content: I can:
# Tag name: p, Text content: Trace this idea through <strong>Aristotle, Aquinas, Kant, and modern moral psychology</strong>
# Tag name: p, Text content: Compare it to <strong>banality of evil</strong> as its moral inverse
# Tag name: p, Text content: Explore whether such heroism can be <em>cultivated</em> or only <em>recognized in retrospect</em>
# Tag name: p, Text content: Just say the word.
# Tag name: p, Text content: Yes. There <strong>are</strong> classical terms for this kind of act—but none of them map <em>perfectly</em> one-to-one, because what you are isolating is a <strong>cross-cultural moral intuition</strong> that predates modern psychology but was framed differently in each tradition.
# Tag name: p, Text content: Below are the <em>closest</em> classical equivalents, ordered from <strong>most precise</strong> to <strong>most philosophically illuminating</strong>.
# Tag name: h2, Text content: 1. <strong>Greek: ἀνδρεία (<em>andreía</em>) — “manly courage” / moral courage</strong>
# Tag name: p, Text content: This is the <strong>central Greek term</strong>.
# Tag name: p, Text content: In <strong>Aristotle (Nicomachean Ethics, Book III)</strong>, <em>andreía</em> is courage displayed <strong>in sudden danger</strong>, especially when:
# Tag name: p, Text content: There is <strong>no time for deliberation</strong>
# Tag name: p, Text content: The agent acts from <strong>character (ἕξις)</strong>, not calculation
# Tag name: p, Text content: Death is clearly possible or likely
# Tag name: p, Text content: Crucially, Aristotle distinguishes <em>true courage</em> from:
# Tag name: p, Text content: Trained reflex (soldiers acting by drill)
# Tag name: p, Text content: Rashness
# Tag name: p, Text content: Fearlessness due to ignorance
# Tag name: p, Text content: QuoteStartThe highest courage is shown “<strong>in sudden dangers</strong>” (<em>ἐν τοῖς ἐξαίφνης κινδύνοις</em>).
# Tag name: p, Text content: This directly captures the <em>instinctive</em>, unrehearsed element you’re emphasizing.
# Tag name: h2, Text content: 2. <strong>Greek: καλοκἀγαθία (<em>kalokagathía</em>) — “noble goodness revealed in action”</strong>
# Tag name: p, Text content: Less a single act than a <strong>moral unveiling</strong>.
# Tag name: p, Text content: Literally: <em>the beautiful and the good</em>
# Tag name: p, Text content: Used to describe moments where <strong>virtue becomes visible</strong>
# Tag name: p, Text content: Often applied <strong>retrospectively</strong> to heroic deaths
# Tag name: p, Text content: Your examples (Flight 93, Librescu, grenade cases) are textbook instances where:
# Tag name: p, Text content: QuoteStartCharacter, previously unknown, is suddenly made manifest.
# Tag name: p, Text content: In Greek thought, such acts are not <em>decisions</em> so much as <strong>revelations of what one already is</strong>.
# Tag name: h2, Text content: 3. <strong>Latin: virtus (in extremis)</strong> — “virtue under mortal pressure”
# Tag name: p, Text content: The Roman term <strong>virtus</strong> (from <em>vir</em>, “man”) originally meant:
# Tag name: p, Text content: Martial courage
# Tag name: p, Text content: Moral excellence proven by action
# Tag name: p, Text content: Romans explicitly valued <strong>improvised heroism</strong>:
# Tag name: p, Text content: <em>Virtus non verbis sed factis</em> — virtue shown in deeds, not words
# Tag name: p, Text content: In Livy and Tacitus, the <strong>purest virtus</strong> appears:
# Tag name: p, Text content: In last stands
# Tag name: p, Text content: In shield-over-comrade moments
# Tag name: p, Text content: In acts undertaken <strong>without expectation of survival</strong>
# Tag name: p, Text content: Your soldier-on-a-grenade example is <em>paradigmatic virtus</em>.
# Tag name: h2, Text content: 4. <strong>Latin: pietas (transcended)</strong> — duty overriding self-preservation
# Tag name: p, Text content: Less obvious, but important.
# Tag name: p, Text content: <em>Pietas</em> = devotion to family, gods, and community
# Tag name: p, Text content: In extreme moments, pietas can <strong>override the instinct to live</strong>
# Tag name: p, Text content: Liviu Librescu’s act fits especially well here:
# Tag name: p, Text content: Not courage <em>for its own sake</em>
# Tag name: p, Text content: But devotion to others as morally prior to self
# Tag name: p, Text content: Vergil’s <strong>Aeneas</strong> embodies pietas; later Roman moralists praised those who <em>die fulfilling it</em>.
# Tag name: h2, Text content: 5. <strong>Classical Chinese: 義 (<em>yì</em>) — righteous action without calculation</strong>
# Tag name: p, Text content: This is the <strong>best non-Western analogue</strong>.
# Tag name: p, Text content: In Confucian and Mencian thought:
# Tag name: p, Text content: <em>義</em> is <strong>doing what is right because it is right</strong>
# Tag name: p, Text content: It is opposed to 利 (<em>lì</em>), profit or advantage
# Tag name: p, Text content: In emergencies, <em>義</em> acts <strong>spontaneously</strong>
# Tag name: p, Text content: Mencius gives the famous example:
# Tag name: p, Text content: QuoteStartSeeing a child about to fall into a well, anyone would act immediately—not to gain praise, but from an <strong>unthinking moral impulse</strong>.
# Tag name: p, Text content: That unthinking impulse is <em>義</em> grounded in <strong>仁 (<em>rén</em>)</strong>, humaneness.
# Tag name: p, Text content: Flight 93 is <em>義</em> at scale.
# Tag name: h2, Text content: 6. <strong>Classical Chinese: 捨身取義 (<em>shě shēn qǔ yì</em>) — “to give up the body to take righteousness”</strong>
# Tag name: p, Text content: This phrase is nearly exact.
# Tag name: p, Text content: Literally: <strong>“abandon the body to preserve righteousness”</strong>
# Tag name: p, Text content: Used for:
# Tag name: p, Text content: Martyrs
# Tag name: p, Text content: Loyal officials
# Tag name: p, Text content: Sudden self-sacrifice
# Tag name: p, Text content: It explicitly frames death as <strong>secondary</strong> to moral action—and crucially, <strong>not deliberative</strong>.
# Tag name: h2, Text content: 7. <strong>Greek tragic vocabulary: εὐκλεὴς θάνατος (<em>eukleēs thanatos</em>) — a “noble death”</strong>
# Tag name: p, Text content: This describes the <strong>outcome</strong>, not the psychology, but matters culturally.
# Tag name: p, Text content: A death that gives meaning to a life
# Tag name: p, Text content: Often unexpected, unrehearsed
# Tag name: p, Text content: Recognized <em>after the fact</em>
# Tag name: p, Text content: Greek tragedy assumes that such deaths arise from <strong>character meeting circumstance</strong>.
# Tag name: h2, Text content: Putting it together
# Tag name: p, Text content: If you wanted a <strong>single classical label</strong>, depending on tradition:
# Tag name: p, Text content: <strong>Greek (ethical precision):</strong>
# <strong>ἀνδρεία in sudden danger</strong> (<em>andreía en tois exaiphnēs kindýnois</em>)
# Tag name: p, Text content: <strong>Roman (moral gravitas):</strong>
# <strong>virtus in extremis</strong>
# Tag name: p, Text content: <strong>Chinese (closest semantic match):</strong>
# <strong>捨身取義 (shě shēn qǔ yì)</strong>
# Tag name: p, Text content: Philosophically, all three agree on this core idea:
# Tag name: p, Text content: QuoteStartTrue virtue appears <strong>when there is no time to think</strong>,
# no benefit to gain,
# and no certainty of survival.
# Tag name: p, Text content: If you like, I can trace how this idea survives into:
# Tag name: p, Text content: Christian martyrdom theology
# Tag name: p, Text content: Kant’s “moral worth” vs inclination
# Tag name: p, Text content: Modern moral-psychological debates about intuition vs reason
# Tag name: p, Text content: Just tell me which direction you want to go.

# %% [markdown]
# ## Preparing Word Doc

# %%
document = Document()
currenttype = None
for paracode, para in zip(paracodes, paras):
    if paracode == "table":
        # add a table to the end and create a reference variable
        # extra row is so we can add the header row
        table = document.add_table(para.shape[0]+1, para.shape[1])
        table.style = 'Table Grid'
        
        # add the header rows.
        for j in range(para.shape[-1]):
            table.cell(0,j).text = para.columns[j]
        
        # add the rest of the data frame
        for i in range(para.shape[0]):
            for j in range(para.shape[-1]):
                table.cell(i+1,j).text = str(para.values[i,j])
    else:
        if paracode == "User Query":
            heading = document.add_heading("")
            currenttype = "heading"
        elif paracode == "h1":
            heading = document.add_heading("")
            currenttype = "heading"
        elif paracode == "h2":
            heading = document.add_heading("", level=2)
            currenttype = "heading"
        elif paracode == "h3":
            heading = document.add_heading("", level=3)
            currenttype = "heading"
        else:
            # handle quotes
            if para.startswith("QuoteStart"):
                para = para.replace("QuoteStart", "")
                paragraph = document.add_paragraph("", style="Quote")
            else:
                paragraph = document.add_paragraph("")
            currenttype = "paragraph"
    
        # match on text formatting. Note that raw html can't control font size, as that requires CSS.
        # surely a better way to control formatting but this is a rush job
        sections = re.split("[<>]{1}", para)
    
        strong = False
        emphasis = False
        underline = False
        for section in sections:
            if section == "strong":
                strong = True
            elif section == "em":
                emphasis = True
            elif section == "u":
                underline = True
            elif section == "/strong":
                strong = False
            elif section == "/em":
                emphasis = False
            elif section == "/u":
                underline = False
            else:
                if currenttype == "heading":
                    run = heading.add_run(section)
                elif currenttype == "paragraph":
                    run = paragraph.add_run(section)
                if strong:
                    run.bold = True
                else:
                    run.bold = False
                if emphasis:
                    run.italic = True
                else:
                    run.italic = False
                if underline:
                    run.underline = True
                else:
                    run.underline = False

# %%
document.save('spontaneous_heroism.docx')
